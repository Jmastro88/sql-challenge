# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import psycopg2

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:4903Uci*@localhost:5432/employee_db')
connection = engine.connect()

# %%
employees=  pd.read_sql('Select * from employees', connection)

# %%
employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
salaries= pd.read_sql('Select * from salaries', connection)

# %%
salaries
# Out:
#         emp_no  salary   from_date     to_date
# 0        10001   60117  1986-06-26  1987-06-26
# 1        10002   65828  1996-08-03  1997-08-03
# 2        10003   40006  1995-12-03  1996-12-02
# 3        10004   40054  1986-12-01  1987-12-01
# 4        10005   78228  1989-09-12  1990-09-12
# ...        ...     ...         ...         ...
# 300019  499995   40000  1997-06-02  1998-06-02
# 300020  499996   58058  1996-05-13  1997-05-13
# 300021  499997   49597  1987-08-30  1988-08-29
# 300022  499998   40000  1993-12-27  1994-12-27
# 300023  499999   63707  1997-11-30  1998-11-30
#
# [300024 rows x 4 columns]

# %%
max_sal=salaries['salary'].max()
min_sal=salaries['salary'].min()

print(f"Max Salary {max_sal}  Min Salary {min_sal}")
# Out:
# Max Salary 129492  Min Salary 40000

# %%
plt.hist(salaries.salary) 

plt.title('Employee Salary Distribution')
plt.ylabel("Number of Employees With Salary")
plt.xlabel('Salary Ranges')
plt.grid()

# %%
title=pd.read_sql('Select * from titles', connection)
title
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
title_salary_combo=title.merge(salaries, on='emp_no', how='inner')

title_salary_combo
# Out:
#         emp_no            title from_date_x   to_date_x  salary from_date_y  \
# 0        10001  Senior Engineer  1986-06-26  9999-01-01   60117  1986-06-26
# 1        10002            Staff  1996-08-03  9999-01-01   65828  1996-08-03
# 2        10003  Senior Engineer  1995-12-03  9999-01-01   40006  1995-12-03
# 3        10004         Engineer  1986-12-01  1995-12-01   40054  1986-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01   40054  1986-12-01
# ...        ...              ...         ...         ...     ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29   49597  1987-08-30
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01   49597  1987-08-30
# 443305  499998     Senior Staff  1998-12-27  9999-01-01   40000  1993-12-27
# 443306  499998            Staff  1993-12-27  1998-12-27   40000  1993-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01   63707  1997-11-30
#
#          to_date_y
# 0       1987-06-26
# ...

# %%
grouped_sal=title_salary_combo.groupby("title")["salary"].mean()

grouped_sal.plot.bar('title','salary', color="pink")

plt.ylabel("Salary")

plt.show()
